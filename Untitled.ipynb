# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv(r"C:\Users\DELL\Desktop\task5.csv")
df
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %% [markdown]
# using .shape method tells that  dataset has 414 rows and 8 columns

# %%
df.shape
# Out:
# (414, 8)

# %% [markdown]
# .head method was just used to print first 5 rows to get a closer look at data

# %%
df.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %% [markdown]
# .info method provides a summary of what data contains that is number of columns, column name, non null count in each column and data type of each column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   No                                      414 non-null    int64
#  1   X1 transaction date                     414 non-null    float64
#  2   X2 house age                            414 non-null    float64
#  3   X3 distance to the nearest MRT station  414 non-null    float64
#  4   X4 number of convenience stores         414 non-null    int64
#  5   X5 latitude                             414 non-null    float64
#  6   X6 longitude                            414 non-null    float64
#  7   Y house price of unit area              414 non-null    float64
# dtypes: float64(6), int64(2)
# memory usage: 26.0 KB

# %% [markdown]
# .isnull method gives the sum of all null values in each column and thus tells us that our dataset has no null value

# %%
df.isnull().sum()
# Out:
# No                                        0
# X1 transaction date                       0
# X2 house age                              0
# X3 distance to the nearest MRT station    0
# X4 number of convenience stores           0
# X5 latitude                               0
# X6 longitude                              0
# Y house price of unit area                0
# dtype: int64

# %% [markdown]
# .describe method tells every necesarry details about the values in each column thus help to understand the numeric aspect

# %%
df.describe()
# Out:
#                No  X1 transaction date  X2 house age  \
# count  414.000000           414.000000    414.000000
# mean   207.500000          2013.148971     17.712560
# std    119.655756             0.281967     11.392485
# min      1.000000          2012.667000      0.000000
# 25%    104.250000          2012.917000      9.025000
# 50%    207.500000          2013.167000     16.100000
# 75%    310.750000          2013.417000     28.150000
# max    414.000000          2013.583000     43.800000
#
#        X3 distance to the nearest MRT station  \
# count                              414.000000
# mean                              1083.885689
# std                               1262.109595
# min                                 23.382840
# 25%                                289.324800
# 50%                                492.231300
# 75%                               1454.279000
# max                               6488.021000
#
# ...

# %%
df['X1 transaction date'] = pd.to_datetime(df['X1 transaction date'])
df
# Out:
#       No           X1 transaction date  X2 house age  \
# 0      1 1970-01-01 00:00:00.000002012          32.0
# 1      2 1970-01-01 00:00:00.000002012          19.5
# 2      3 1970-01-01 00:00:00.000002013          13.3
# 3      4 1970-01-01 00:00:00.000002013          13.3
# 4      5 1970-01-01 00:00:00.000002012           5.0
# ..   ...                           ...           ...
# 409  410 1970-01-01 00:00:00.000002013          13.7
# 410  411 1970-01-01 00:00:00.000002012           5.6
# 411  412 1970-01-01 00:00:00.000002013          18.8
# 412  413 1970-01-01 00:00:00.000002013           8.1
# 413  414 1970-01-01 00:00:00.000002013           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# ...

# %%
    # Iterate through each row in the CSV
    for row in df:
        no = row['No']
        floating_date = float(row['X1 transaction date'])

        # Separate the year
        year = int(floating_date)
        
        print(f"No: {name}, Year: {year}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 3
#       1 # Iterate through each row in the CSV
#       2 for row in df:
# ----> 3     no = row['No']
#       4     floating_date = float(row['X1 transaction date'])
#       6     # Separate the year
#
# TypeError: string indices must be integers, not 'str'

# %% [markdown]
#  .nunique() method in Pandas is used to count the number of unique or distinct values in a  DataFrame

# %%
df.nunique()
# Out:
# No                                        414
# X1 transaction date                         2
# X2 house age                              236
# X3 distance to the nearest MRT station    259
# X4 number of convenience stores            11
# X5 latitude                               234
# X6 longitude                              232
# Y house price of unit area                270
# dtype: int64

# %% [markdown]
# the below histograms reveal the variation of individual column values to the number of houses for a more clear picture of distribution.

# %%
plt.hist(df['X2 house age'],bins=10)  # Adjust the number of bins as needed
plt.xlabel('house age')  # Replace with a label for the x-axis
plt.ylabel('number')  # Replace with a label for the y-axis
plt.show()
plt.hist(df['X3 distance to the nearest MRT station'],bins=10)  #
plt.xlabel('distance from nearest metro')  
plt.ylabel('number')  
plt.show()
plt.hist(df['X4 number of convenience stores'],bins=10)  
plt.xlabel('stores nearby')  
plt.ylabel('number')  
plt.show()
plt.hist(df['X5 latitude'],bins=10)  
plt.xlabel('latitude')  
plt.ylabel('number')  
plt.show()
plt.hist(df['X6 longitude'],bins=10)  
plt.xlabel('longitude')  
plt.ylabel('number')  
plt.show()
plt.hist(df['Y house price of unit area'],bins=10)  
plt.xlabel('price of unit area') 
plt.ylabel('number')  
plt.show()

# %% [markdown]
# the below given bar chart depicts that all the houses provided have almost same variation of longitude with latitude within all the values thus all are at almost same location wrt the four directions

# %%
column1 = 'X6 longitude'
column2 = 'X5 latitude'
plt.bar(df[column1], df[column2])
plt.xlabel(column1)
plt.ylabel(column2)
plt.title('Vertical Bar Chart Between {} and {}'.format(column1, column2))

# Rotate x-axis labels for better readability if necessary
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# below bar is to show that as distance varies how many stores can be plotted to get a better idea of the surroundings

# %%
column1 = 'X4 number of convenience stores'
column2 = 'X3 distance to the nearest MRT station'
plt.bar(df[column1], df[column2])
plt.xlabel(column1)
plt.ylabel(column2)
plt.title('Vertical Bar Chart Between {} and {}'.format(column1, column2))

# Rotate x-axis labels for better readability if necessary
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# the below bar is showing variation of  house age with price so that if higher price is offered for an older house than a new house could be caught

# %%
column1 = 'X2 house age'
column2 = 'Y house price of unit area'
plt.bar(df[column1], df[column2])
plt.xlabel(column1)
plt.ylabel(column2)
plt.title('Vertical Bar Chart Between {} and {}'.format(column1, column2))

# Rotate x-axis labels for better readability if necessary
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# relation between transaction dates and price is necessary for the suitable bifercation of the data

# %%
column1 = 'X1 transaction date'
column2 = 'Y house price of unit area'
plt.bar(df[column1], df[column2])
plt.xlabel(column1)
plt.ylabel(column2)
plt.title('Vertical Bar Chart Between {} and {}'.format(column1, column2))

# Rotate x-axis labels for better readability if necessary
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv(r"C:\Users\DELL\Desktop\task5.csv")
h=df.corr(numeric_only=True)
h
# Out:
#                                               No  X1 transaction date  \
# No                                      1.000000            -0.048658
# X1 transaction date                    -0.048658             1.000000
# X2 house age                           -0.032808             0.017549
# X3 distance to the nearest MRT station -0.013573             0.060880
# X4 number of convenience stores        -0.012699             0.009635
# X5 latitude                            -0.010110             0.035058
# X6 longitude                           -0.011059            -0.041082
# Y house price of unit area             -0.028587             0.087491
#
#                                         X2 house age  \
# No                                         -0.032808
# X1 transaction date                         0.017549
# X2 house age                                1.000000
# X3 distance to the nearest MRT station      0.025622
# X4 number of convenience stores             0.049593
# ...

# %%
import seaborn as sns
sns.heatmap(df.corr(),annot = True)
plt.show()

# %%
g1=df.groupby('X4 number of convenience stores',as_index=False)['Y house price of unit area'].mean()
g1
# g3=df.groupby('X6 longitude',as_index=False)['Y house price of unit area'].mean()
# g3
# Out:
#     X4 number of convenience stores  Y house price of unit area
# 0                                 0                   26.462687
# 1                                 1                   31.839130
# 2                                 2                   31.412500
# 3                                 3                   29.536957
# 4                                 4                   37.474194
# 5                                 5                   44.729851
# 6                                 6                   46.951351
# 7                                 7                   43.848387
# 8                                 8                   44.696667
# 9                                 9                   51.732000
# 10                               10                   48.430000

# %%
 g2=df.groupby('X5 latitude',as_index=False)['Y house price of unit area'].mean()
 g2
# Out:
#      X5 latitude  Y house price of unit area
# 0       24.93207                   29.300000
# 1       24.93293                   45.100000
# 2       24.93363                   29.300000
# 3       24.93885                   16.933333
# 4       24.94155                   16.457143
# ..           ...                         ...
# 229     24.99156                   33.250000
# 230     24.99176                   35.400000
# 231     24.99800                   41.200000
# 232     25.00115                   46.600000
# 233     25.01459                   27.300000
#
# [234 rows x 2 columns]

# %%
plt.bar(g1['X4 number of convenience stores'], g1['Y house price of unit area'])
plt.xlabel('X4 number of convenience stores')
plt.ylabel('Y house price of unit area')
plt.title('Bar Graph')
plt.show()

# %% [markdown]
# therefore this shows that variation of latitude and longitude has not that much interference within the dataset

# %%
plt.bar(g2['X5 latitude'],g2 ['Y house price of unit area'])
plt.xlabel('X5 latitude')
plt.ylabel('Y house price of unit area')
plt.title('Bar Graph')
plt.show()

# %%
sns.lineplot(x = 'X4 number of convenience stores', y = 'Y house price of unit area', data = g1)
plt.show()
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %%
sns.barplot(x='X4 number of convenience stores',y='Y house price of unit area',hue='X1 transaction date',data=df)
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %% [markdown]
# therefore from above scenario some things can be concluded:
# other columns have negative or almost negligible realtionship among each other as seen from the heat map
# column latitude can be neglected from data set has it does not vary that much with respect to others
# same goes for longitude
# major impact can be seen from variation of number of convinience stores with house price
