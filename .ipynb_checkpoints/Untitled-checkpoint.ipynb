# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv(r"C:\Users\DELL\Desktop\task5.csv")
df
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# 4                                 390.56840                                5
# ..                                      ...                              ...
# 409                              4082.01500                                0
# 410                                90.45606                                9
# 411                               390.96960                                7
# 412                               104.81010                                5
# 413                                90.45606                                9
#
#      X5 latitude  X6 longitude  Y house price of unit area
# 0       24.98298     121.54024                        37.9
# 1       24.98034     121.53951                        42.2
# 2       24.98746     121.54391                        47.3
# 3       24.98746     121.54391                        54.8
# 4       24.97937     121.54245                        43.1
# ..           ...           ...                         ...
# 409     24.94155     121.50381                        15.4
# 410     24.97433     121.54310                        50.0
# 411     24.97923     121.53986                        40.6
# 412     24.96674     121.54067                        52.5
# 413     24.97433     121.54310                        63.9
#
# [414 rows x 8 columns]

# %% [markdown]
# using .shape method tells that  dataset has 414 rows and 8 columns

# %%
df.shape
# Out:
# (414, 8)

# %% [markdown]
# .head method was just used to print first 5 rows to get a closer look at data

# %%
df.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# 3     24.98746     121.54391                        54.8
# 4     24.97937     121.54245                        43.1

# %% [markdown]
# .info method provides a summary of what data contains that is number of columns, column name, non null count in each column and data type of each column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   No                                      414 non-null    int64
#  1   X1 transaction date                     414 non-null    float64
#  2   X2 house age                            414 non-null    float64
#  3   X3 distance to the nearest MRT station  414 non-null    float64
#  4   X4 number of convenience stores         414 non-null    int64
#  5   X5 latitude                             414 non-null    float64
#  6   X6 longitude                            414 non-null    float64
#  7   Y house price of unit area              414 non-null    float64
# dtypes: float64(6), int64(2)
# memory usage: 26.0 KB

# %% [markdown]
# .isnull method gives the sum of all null values in each column and thus tells us that our dataset has no null value

# %%
df.isnull().sum()
# Out:
# No                                        0
# X1 transaction date                       0
# X2 house age                              0
# X3 distance to the nearest MRT station    0
# X4 number of convenience stores           0
# X5 latitude                               0
# X6 longitude                              0
# Y house price of unit area                0
# dtype: int64

# %% [markdown]
# .describe method tells every necesarry details about the values in each column thus help to understand the numeric aspect

# %%
df.describe()
# Out:
#                No  X1 transaction date  X2 house age  \
# count  414.000000           414.000000    414.000000
# mean   207.500000          2013.148971     17.712560
# std    119.655756             0.281967     11.392485
# min      1.000000          2012.667000      0.000000
# 25%    104.250000          2012.917000      9.025000
# 50%    207.500000          2013.167000     16.100000
# 75%    310.750000          2013.417000     28.150000
# max    414.000000          2013.583000     43.800000
#
#        X3 distance to the nearest MRT station  \
# count                              414.000000
# mean                              1083.885689
# std                               1262.109595
# min                                 23.382840
# 25%                                289.324800
# 50%                                492.231300
# 75%                               1454.279000
# max                               6488.021000
#
#        X4 number of convenience stores  X5 latitude  X6 longitude  \
# count                       414.000000   414.000000    414.000000
# mean                          4.094203    24.969030    121.533361
# std                           2.945562     0.012410      0.015347
# min                           0.000000    24.932070    121.473530
# 25%                           1.000000    24.963000    121.528085
# 50%                           4.000000    24.971100    121.538630
# 75%                           6.000000    24.977455    121.543305
# max                          10.000000    25.014590    121.566270
#
#        Y house price of unit area
# count                  414.000000
# mean                    37.980193
# std                     13.606488
# min                      7.600000
# 25%                     27.700000
# 50%                     38.450000
# 75%                     46.600000
# max                    117.500000

# %%
df['X1 transaction date']=pd.to_datetime(df['X1 transaction date'],format='%Y%m%d')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 df['X1 transaction date']=pd.to_datetime(df['X1 transaction date'],format='%Y%m%d')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\tools\datetimes.py:1108, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1106             result = arg.tz_localize("utc")
#    1107 elif isinstance(arg, ABCSeries):
# -> 1108     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1109     if not cache_array.empty:
#    1110         result = arg.map(cache_array)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\tools\datetimes.py:254, in _maybe_cache(arg, format, cache, convert_listlike)
#     252 unique_dates = unique(arg)
#     253 if len(unique_dates) < len(arg):
# --> 254     cache_dates = convert_listlike(unique_dates, format)
#     255     # GH#45319
#     256     try:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\tools\datetimes.py:488, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     486 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     487 if format is not None and format != "mixed":
# --> 488     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     490 result, tz_parsed = objects_to_datetime64ns(
#     491     arg,
#     492     dayfirst=dayfirst,
#    (...)
#     496     allow_object=True,
#     497 )
#     499 if tz_parsed is not None:
#     500     # We can take a shortcut since the datetime64 numpy array
#     501     # is in UTC
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\tools\datetimes.py:519, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     508 def _array_strptime_with_fallback(
#     509     arg,
#     510     name,
#    (...)
#     514     errors: str,
#     515 ) -> Index:
#     516     """
#     517     Call array_strptime, with fallback behavior depending on 'errors'.
#     518     """
# --> 519     result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     520     if any(tz is not None for tz in timezones):
#     521         return _return_parsed_timezone_results(result, timezones, utc, name)
#
# File strptime.pyx:534, in pandas._libs.tslibs.strptime.array_strptime()
#
# File strptime.pyx:355, in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data "01/01/70" doesn't match format "%Y%m%d", at position 0. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %% [markdown]
#  .nunique() method in Pandas is used to count the number of unique or distinct values in a  DataFrame

# %%
df.nunique()
# Out:
# No                                        414
# X1 transaction date                        12
# X2 house age                              236
# X3 distance to the nearest MRT station    259
# X4 number of convenience stores            11
# X5 latitude                               234
# X6 longitude                              232
# Y house price of unit area                270
# dtype: int64

# %% [markdown]
# the below histograms reveal the variation of individual column values to the number of houses for a more clear picture of distribution.

# %%
plt.hist(df['X2 house age'],bins=10)  # Adjust the number of bins as needed
plt.xlabel('house age')  # Replace with a label for the x-axis
plt.ylabel('number')  # Replace with a label for the y-axis
plt.show()
plt.hist(df['X3 distance to the nearest MRT station'],bins=10)  #
plt.xlabel('distance from nearest metro')  
plt.ylabel('number')  
plt.show()
plt.hist(df['X4 number of convenience stores'],bins=10)  
plt.xlabel('stores nearby')  
plt.ylabel('number')  
plt.show()
plt.hist(df['X5 latitude'],bins=10)  
plt.xlabel('latitude')  
plt.ylabel('number')  
plt.show()
plt.hist(df['X6 longitude'],bins=10)  
plt.xlabel('longitude')  
plt.ylabel('number')  
plt.show()
plt.hist(df['Y house price of unit area'],bins=10)  
plt.xlabel('price of unit area') 
plt.ylabel('number')  
plt.show()

# %% [markdown]
# the below given bar chart depicts that all the houses provided have almost same variation of longitude with latitude within all the values.thus almost same area can be assumed

# %%
column1 = 'X6 longitude'
column2 = 'X5 latitude'
plt.bar(df[column1], df[column2])
plt.xlabel(column1)
plt.ylabel(column2)
plt.title('Vertical Bar Chart Between {} and {}'.format(column1, column2))

# Rotate x-axis labels for better readability if necessary
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# below bar is to show that as distance varies how many stores can be plotted to get a better idea of the surroundings

# %%
column1 = 'X3 distance to the nearest MRT station'
column2 = 'X4 number of convenience stores'
plt.bar(df[column1], df[column2])
plt.xlabel(column1)
plt.ylabel(column2)
plt.title('Vertical Bar Chart Between {} and {}'.format(column1, column2))

# Rotate x-axis labels for better readability if necessary
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# the below bar is showing variation of  house age with price so that if higher price is offered for an older house than a new house could be caught

# %%
column1 = 'X2 house age'
column2 = 'Y house price of unit area'
plt.bar(df[column1], df[column2])
plt.xlabel(column1)
plt.ylabel(column2)
plt.title('Vertical Bar Chart Between {} and {}'.format(column1, column2))

# Rotate x-axis labels for better readability if necessary
plt.xticks(rotation=45)
plt.show()
